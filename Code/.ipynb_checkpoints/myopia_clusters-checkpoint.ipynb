# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.preprocessing import StandardScaler

# %%
#Read myopia.csv into a Pandas Dataframe
path = ("/Users/mr19th/Desktop/homework/20-Unsupervised-Learning/Starter_Code/myopia.csv")
df_myopia = pd.read_csv(path)
df_myopia.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
#Remove the "MYOPIC" column
df=df_myopia.drop(['MYOPIC'], axis=1)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0        0    10         34      1      1
# 1        1     7         12      1      1
# 2        0    10         14      0      0
# 3        0     4         37      0      1
# 4        0     4          4      1      0

# %%
#Standardize dataset into small values
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
#Apply Dimensionality Reduction
pca = PCA(n_components=0.90)
pca_data = pca.fit_transform(scaled_data)

# %%
#Get the desired vairance ratio
pca.explained_variance_ratio_
# Out:
# array([0.21177355, 0.15659716, 0.08688023, 0.08301762, 0.07584858,
#        0.06997878, 0.06486986, 0.06377808, 0.05393666, 0.05205566])

# %%
#Run t-SNE
tsne = TSNE(learning_rate=50)
transformed_features = tsne.fit_transform(pca_data)
# Out:
# /Users/mr19th/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
#Check dimensions 
pca_data.shape
# Out:
# (618, 10)

# %%
df["X"] = transformed_features[:,0]
df["y"] = transformed_features[:,1]
df["Myopic"] = df_myopia["MYOPIC"]
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY          X          y  Myopic
# 0        0    10         34      1      1  -7.411266  -8.587431       1
# 1        1     7         12      1      1  22.985926  -5.381073       0
# 2        0    10         14      0      0  -2.973685  17.428381       0
# 3        0     4         37      0      1 -12.446815  11.425532       1
# 4        0     4          4      1      0  11.834064 -19.352097       0

# %%
#Plot the dataset
plt.scatter(df["X"], df["y"])
plt.show()

# %%
#Plot the dataset 
plt.scatter(df["X"], df["y"], c=df["Myopic"])
plt.show()

# %%
df_myopia_pca = pd.DataFrame(data=pca_data, columns=["component 1", "component 2",
                                                                "component 3","component 4",
                                                                 "component 5","component 6",
                                                                 "component 7",
                                                                 "component 8","component 9",
                                                                 "omponent 10"])
df_myopia_pca.head()
# Out:
#    component 1  component 2  component 3  component 4  component 5  \
# 0     0.535503     1.145004    -1.385019     0.116006    -3.226691
# 1    -0.624706    -1.575786    -0.794253     1.156287     0.292256
# 2    -0.933479    -0.717076     0.820150    -1.547638     0.173941
# 3     0.106354     1.192475    -0.024441     1.507469    -2.356836
# 4    -0.388503    -2.839655    -0.229767    -0.622510     0.271458
#
#    component 6  component 7  component 8  component 9  omponent 10
# 0    -1.928459    -1.958892    -1.922997     0.026753     0.178144
# 1     0.349060    -0.455206     0.285332     0.689683    -0.557031
# 2     0.272783     0.025821    -0.030817    -0.431499     0.013336
# 3    -0.023139     0.236418    -1.717109    -1.230785    -0.703400
# 4    -0.928956     0.537900    -1.301787     0.279007     0.631183

# %%
#Find the best value for k
inertia = []
k = list(range(1, 11))

#Calculate the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df_myopia_pca)
    inertia.append(km.inertia_)

#Create the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(1,11)))
plt.title('Myopia Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# Can the patients be clustered?
#
# -The data is inconclusive to determine if the patients can be clustered. If additional dimensions/samples were added, the data should help determine whether our patients are myopic or not.
#
# If so, into how many clusters?
#
# -Inconclusive
